# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://citrus_user:sM9MrUjDKMzbzYVs@cluster0-ak1hs.mongodb.net/test?retryWrites=true&w=majority")
db = client.test

# %%
table = db.table_name

# %%
table.find_one({'_id':5})
# Out:
# {'_id': 5,
#  'name_with_com': 'Clanton, AL',
#  'city_no_st': 'Clanton',
#  'census_full_name': 'Clanton city, Alabama',
#  'City': 'Clanton AL',
#  'State': 'Alabama',
#  'st': 'AL',
#  'geo_id': '1600000US0115136',
#  'Latitude': 32.8439,
#  'Longitude': -86.62299999999998,
#  'Total Population': 8724.0,
#  'Population Male & Female': {'Male': 46.5, 'Female': 53.5},
#  'Age Distribution': {'Under 5': 8.4,
#   '5 to 9': 5.4,
#   '10 to 14': 6.4,
#   '15 to 19': 4.4,
#   '20 to 24': 4.0,
#   '25 to 34': 16.5,
#   '35 to 44': 12.8,
#   '45 to 54': 13.1,
#   '55 to 59': 5.9,
#   '60 to 64': 7.2,
#   '65 to 74': 9.3,
#   '75 to 84': 4.9,
#   '85 years and over': 1.6},
#  'Median Age': 39.3,
#  'Population under 18': 23.4,
#  'Population over 16': 79.4,
#  'Ethnicity': {'White': 69.0,
#   'Hispanic or Latino': 6.7,
#   'African American': 20.7,
#   'American Indian': 0.0,
#   'Asian': 2.0,
#   'Pacific Islander': 0.0,
#   'other race': 0.0,
#   'Two or more races': 1.6},
# ...
